# %% [markdown]
# ###인공지능 10월28일 수업

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_excel("C:/ai/test/data/excel-comp-data.xlsx")

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dlfdl\miniconda3\envs\ml\python.exe

# %%
import openpyxl
print(openpyxl.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import openpyxl
#       2 print(openpyxl.__version__)
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
where python
# Out:
#   Cell In[5], line 1
#     where python
#           ^
# SyntaxError: invalid syntax
